# %%
from math import exp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sbn
# %matplotlib inline
sbn.set_style("whitegrid")

value_fn = pd.read_csv('./value-func.txt',sep=" ")
ax=value_fn.plot(x='queue',y='value')
ax.set_ylabel("Value Function")
ax.set_xlim([0,20])



policy = pd.read_csv('./optimal-policy.txt',sep=" ")
ax = policy.plot(x='queue',y='value')
ax.set_ylabel("Optimal Policy")
ax.set_xlim([0,20])


rho = pd.read_csv('./rho.txt',sep=" ")
ax=rho.plot(x='bid',y='value')
ax.set_ylabel("rho CDF")
ax.set_xlim([0,100])
ax.set_ylim([0,1.2])


pi = pd.read_csv('./pi-func.txt',sep=" ")
ax=pi.plot(x='queue',y='value')
ax.set_ylabel("PI CDF")
ax.set_ylim([0,1.2])
ax.set_xlim([0,8])
# Out:
# (0, 8)
